# %%
# !pip install ultralytics
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="RBr7ffKmLSB100a0nrUZ")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:00<00:00, 4553.05it/s]

# %%
import shutil

shutil.move('football-players-detection-1/train', 'football-players-detection-1/football-players-detection-1/train')
shutil.move('football-players-detection-1/test', 'football-players-detection-1/football-players-detection-1/test')
shutil.move('football-players-detection-1/valid', 'football-players-detection-1/football-players-detection-1/valid')
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %%
dataset.location
# Out:
# '/Users/michaelpotishman/Documents/University/Individual Work/GitHub/Machine Learning/Football Analyser With Yolo/training/football-players-detection-1'

# %%
# !yolo task=detect mode=train model=yolov5l.pt data="/Users/michaelpotishman/Documents/University/Individual Work/GitHub/Machine Learning/Football Analyser With Yolo/training/football-players-detection-1/data.yaml" epochs=100 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5l.pt' with new 'model=yolov5lu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# Ultralytics 8.4.40 🚀 Python-3.12.4 torch-2.11.0 CPU (Apple M2)
# ...
